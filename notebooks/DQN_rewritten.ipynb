# %% [markdown]
# # DQN Experiments
#
# This notebook evaluates the DQN (Deep Q-Network) agent on the TestEnv environment.
# We analyze convergence, cumulative reward, and policy stability under different hyperparameter settings. <br>
#
# All algorithm code is implemented in `src/models/DQNN.py`. <br>
# This notebook only shows the direct implementation of an experiment and analysis of the results.
#
# We perform the following experiments:
#
# - DQN with reward shaping and 5 bins <br>

# %%
# We import the necessary libraries and modules
import sys
import os

project_root = os.path.abspath("..")
sys.path.append(project_root)

from stable_baselines3 import DQN
from src.env.TestEnv import HydroElectric_Test
from src.models.DQN import DQNWrapper
from src.utils.visualizations import *
import optuna
import numpy as np
import random

# %% [markdown]
# ### Hyperparameter optimization
#
# We want to optimize the hyperparameters of the model first. To do this, we set a random seed and perform an optuna study.

# %%
# We set a random seed for reproducibility
SEED = 5
np.random.seed(SEED)
random.seed(SEED)

# %%
# We set the experiment configurations
NUM_ACTIONS = 5
REWARD_SHAPING = True

TRAIN_CONFIG = {
    "learning_rate": 1e-4,
    "batch_size": 128,
    "exploration_final_eps": 0.05,
    "buffer_size": 50000,
    "learning_starts": 5000,
    "train_freq": 4,
    "gradient_steps": 1,
    "target_update_interval": 1000,
    "gamma": 0.99,
    "exploration_fraction": 0.3,
    "exploration_initial_eps": 1.0,
    "total_timesteps": 100000,
}

parameter_dict = {
    'learning_rate': (1e-5, 1e-3),
    'batch_size': [32, 64, 128, 256],
    'exploration_final_eps': (0.01, 0.1),
}

# %%
# We initialize the training environment
train_path = os.path.abspath("data/train.xlsx")
train_env_raw = HydroElectric_Test(train_path)
train_env = DQNWrapper(train_env_raw, reward_shape=REWARD_SHAPING, num_actions=NUM_ACTIONS)
train_env.reset(seed=SEED)

# We initialize the validation environment
val_path = os.path.abspath("data/validate.xlsx")
val_env_raw = HydroElectric_Test(val_path)
val_env = DQNWrapper(val_env_raw, reward_shape=REWARD_SHAPING, num_actions=NUM_ACTIONS)
val_env.reset(seed=SEED)
# Out:
# (array([0.5       , 0.00440147, 0.        , 0.6666667 , 0.        ],
#        dtype=float32),
#  {})

# %%
def objective(trial):
    # Suggest hyperparameters
    learning_rate = trial.suggest_float("learning_rate", parameter_dict["learning_rate"][0], parameter_dict["learning_rate"][1], log=True)
    batch_size = trial.suggest_categorical("batch_size", parameter_dict["batch_size"])
    exploration_final_eps = trial.suggest_float("exploration_final_eps", parameter_dict["exploration_final_eps"][0], parameter_dict["exploration_final_eps"][1], log=True)

    # Update train config with suggested hyperparameters
    TRAIN_CONFIG["learning_rate"] = learning_rate
    TRAIN_CONFIG["batch_size"] = int(batch_size)
    TRAIN_CONFIG["exploration_final_eps"] = exploration_final_eps

    # Create and train model
    policy_kwargs = dict(net_arch=[256, 256, 128])
    model = DQN(
        "MlpPolicy",
        train_env,
        verbose=0,
        learning_rate=TRAIN_CONFIG["learning_rate"],
        buffer_size=TRAIN_CONFIG["buffer_size"],
        learning_starts=TRAIN_CONFIG["learning_starts"],
        batch_size=TRAIN_CONFIG["batch_size"],
        train_freq=TRAIN_CONFIG["train_freq"],
        gradient_steps=TRAIN_CONFIG["gradient_steps"],
        target_update_interval=TRAIN_CONFIG["target_update_interval"],
        gamma=TRAIN_CONFIG["gamma"],
        exploration_fraction=TRAIN_CONFIG["exploration_fraction"],
        exploration_initial_eps=TRAIN_CONFIG["exploration_initial_eps"],
        exploration_final_eps=TRAIN_CONFIG["exploration_final_eps"],
        policy_kwargs=policy_kwargs,
    )

    # Train the model
    model.learn(total_timesteps=TRAIN_CONFIG["total_timesteps"], log_interval=10)

    # Evaluate on validation environment
    val_env.reset(seed=SEED)
    val_env.reward_shape = False  # Disable reward shaping for evaluation
    
    obs, _ = val_env.reset(seed=SEED)
    obs = np.array(obs, dtype=np.float32)
    done = False
    episode_rewards = []
    
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        action = int(action)
        obs, reward, terminated, truncated, _ = val_env.step(action)
        done = terminated or truncated
        episode_rewards.append(reward)
        obs = np.array(obs, dtype=np.float32)
    
    total_reward = sum(episode_rewards)
    return total_reward

# %% [markdown]
# ### Experiment 1: 5 Bins / Reward Shaping

# %%
# Run Optuna study for hyperparameter optimization
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2026-01-28 21:07:48,937] A new study created in memory with name: no-name-db7d8220-5de4-49ce-b439-47c254bb3772
# [I 2026-01-28 21:08:43,189] Trial 0 finished with value: 57065.78937684518 and parameters: {'learning_rate': 0.0005515459875374307, 'batch_size': 128, 'exploration_final_eps': 0.01547493293344383}. Best is trial 0 with value: 57065.78937684518.
# [I 2026-01-28 21:09:40,750] Trial 1 finished with value: 51857.74282453631 and parameters: {'learning_rate': 0.000526426699784957, 'batch_size': 128, 'exploration_final_eps': 0.023734117113630777}. Best is trial 0 with value: 57065.78937684518.
# [I 2026-01-28 21:10:38,258] Trial 2 finished with value: 19061.029104561134 and parameters: {'learning_rate': 0.00024430338625906593, 'batch_size': 128, 'exploration_final_eps': 0.024068450548678077}. Best is trial 0 with value: 57065.78937684518.
# [I 2026-01-28 21:11:32,554] Trial 3 finished with value: 8.740716992568 and parameters: {'learning_rate': 1.9362383121171407e-05, 'batch_size': 64, 'exploration_final_eps': 0.07938239077735984}. Best is trial 0 with value: 57065.78937684518.
# [I 2026-01-28 21:12:19,704] Trial 4 finished with value: 50177.86351013396 and parameters: {'learning_rate': 0.0008991352080083088, 'batch_size': 32, 'exploration_final_eps': 0.08069197475855373}. Best is trial 0 with value: 57065.78937684518.
# [I 2026-01-28 21:13:05,004] Trial 5 finished with value: 0.0 and parameters: {'learning_rate': 1.2605555934626615e-05, 'batch_size': 32, 'exploration_final_eps': 0.014190212178010798}. Best is trial 0 with value: 57065.78937684518.
# [I 2026-01-28 21:13:55,714] Trial 6 finished with value: 57575.352658245334 and parameters: {'learning_rate': 0.00060103542046879, 'batch_size': 128, 'exploration_final_eps': 0.016796024015881737}. Best is trial 6 with value: 57575.352658245334.
# [I 2026-01-28 21:14:46,682] Trial 7 finished with value: 51588.94043449451 and parameters: {'learning_rate': 0.0003969516622473454, 'batch_size': 128, 'exploration_final_eps': 0.01444065150288575}. Best is trial 6 with value: 57575.352658245334.
# [I 2026-01-28 21:15:46,978] Trial 8 finished with value: 48.2461090968564 and parameters: {'learning_rate': 2.6909196141271217e-05, 'batch_size': 256, 'exploration_final_eps': 0.026050365662193046}. Best is trial 6 with value: 57575.352658245334.
# [I 2026-01-28 21:16:46,505] Trial 9 finished with value: 17.481433985136 and parameters: {'learning_rate': 2.0689591488955313e-05, 'batch_size': 256, 'exploration_final_eps': 0.01290513110822714}. Best is trial 6 with value: 57575.352658245334.
# [I 2026-01-28 21:17:38,459] Trial 10 finished with value: 2713.107518234288 and parameters: {'learning_rate': 9.470390846129834e-05, 'batch_size': 64, 'exploration_final_eps': 0.045948426085456476}. Best is trial 6 with value: 57575.352658245334.
# [I 2026-01-28 21:18:36,345] Trial 11 finished with value: 3390.7110020666314 and parameters: {'learning_rate': 0.00015126270529424896, 'batch_size': 128, 'exploration_final_eps': 0.011151360608498018}. Best is trial 6 with value: 57575.352658245334.
# [I 2026-01-28 21:19:32,333] Trial 12 finished with value: 65713.7235195619 and parameters: {'learning_rate': 0.0009110110703168337, 'batch_size': 128, 'exploration_final_eps': 0.01791741522251463}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:20:27,988] Trial 13 finished with value: 60510.598852565454 and parameters: {'learning_rate': 0.0009838736085400887, 'batch_size': 128, 'exploration_final_eps': 0.04046242027760632}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:21:24,758] Trial 14 finished with value: -71.2633305106188 and parameters: {'learning_rate': 6.773847593299699e-05, 'batch_size': 128, 'exploration_final_eps': 0.04329012938375185}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:22:21,409] Trial 15 finished with value: 57755.18992648997 and parameters: {'learning_rate': 0.0009641182843277928, 'batch_size': 128, 'exploration_final_eps': 0.040623563912676096}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:23:24,801] Trial 16 finished with value: 32400.846876281776 and parameters: {'learning_rate': 0.0002504663156467063, 'batch_size': 256, 'exploration_final_eps': 0.05811415860181848}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:24:18,545] Trial 17 finished with value: 0.0 and parameters: {'learning_rate': 4.505070761997969e-05, 'batch_size': 64, 'exploration_final_eps': 0.03237812134500643}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:25:09,756] Trial 18 finished with value: 13490.152953738718 and parameters: {'learning_rate': 0.0002445495768200001, 'batch_size': 32, 'exploration_final_eps': 0.019250474137318837}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:26:06,061] Trial 19 finished with value: 21928.888474721738 and parameters: {'learning_rate': 0.00036512907448756196, 'batch_size': 128, 'exploration_final_eps': 0.032514853326722555}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:27:02,545] Trial 20 finished with value: 2495.2914994816033 and parameters: {'learning_rate': 0.00014522099991019454, 'batch_size': 128, 'exploration_final_eps': 0.05957260718825397}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:28:00,052] Trial 21 finished with value: 59970.28479356443 and parameters: {'learning_rate': 0.0009414157510885943, 'batch_size': 128, 'exploration_final_eps': 0.04069798641308163}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:28:56,229] Trial 22 finished with value: 61594.315201912985 and parameters: {'learning_rate': 0.0009698235055410265, 'batch_size': 128, 'exploration_final_eps': 0.05440927313908965}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:29:52,412] Trial 23 finished with value: 55041.157201890615 and parameters: {'learning_rate': 0.0006963259301055736, 'batch_size': 128, 'exploration_final_eps': 0.05805556832117006}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:30:49,623] Trial 24 finished with value: 31804.016994193258 and parameters: {'learning_rate': 0.0003995428832121194, 'batch_size': 128, 'exploration_final_eps': 0.06576701997223357}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:31:46,341] Trial 25 finished with value: 53228.771372858115 and parameters: {'learning_rate': 0.0007511878980827433, 'batch_size': 128, 'exploration_final_eps': 0.049630150354887076}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:32:50,423] Trial 26 finished with value: 51938.31008911482 and parameters: {'learning_rate': 0.0003353852562015995, 'batch_size': 256, 'exploration_final_eps': 0.09145465414623376}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:33:41,475] Trial 27 finished with value: 26748.733192094376 and parameters: {'learning_rate': 0.0005048735067307667, 'batch_size': 32, 'exploration_final_eps': 0.028785996374835147}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:34:34,480] Trial 28 finished with value: 58346.84968919264 and parameters: {'learning_rate': 0.0007115799133456707, 'batch_size': 64, 'exploration_final_eps': 0.01997207521196405}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:35:29,290] Trial 29 finished with value: 5159.066204999671 and parameters: {'learning_rate': 0.00016863408196644223, 'batch_size': 128, 'exploration_final_eps': 0.05232142173511812}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:36:24,675] Trial 30 finished with value: 55942.49103558208 and parameters: {'learning_rate': 0.0005031136824392685, 'batch_size': 128, 'exploration_final_eps': 0.010095971005811473}. Best is trial 12 with value: 65713.7235195619.
# [I 2026-01-28 21:37:20,052] Trial 31 finished with value: 68603.36335527191 and parameters: {'learning_rate': 0.0009638038112182319, 'batch_size': 128, 'exploration_final_eps': 0.0388671486044139}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:38:15,366] Trial 32 finished with value: 52203.743150211245 and parameters: {'learning_rate': 0.0005981010882272129, 'batch_size': 128, 'exploration_final_eps': 0.03587716730011568}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:39:14,620] Trial 33 finished with value: 60708.97544151634 and parameters: {'learning_rate': 0.0009937235772627146, 'batch_size': 128, 'exploration_final_eps': 0.03614086332597245}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:40:11,130] Trial 34 finished with value: 60174.41916224701 and parameters: {'learning_rate': 0.0007470282349964324, 'batch_size': 128, 'exploration_final_eps': 0.021069934333908337}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:41:06,729] Trial 35 finished with value: 48031.48954653593 and parameters: {'learning_rate': 0.0004847555071415209, 'batch_size': 128, 'exploration_final_eps': 0.02784291471047986}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:42:01,778] Trial 36 finished with value: 66919.61321614774 and parameters: {'learning_rate': 0.0007261614907563244, 'batch_size': 128, 'exploration_final_eps': 0.03624752095306028}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:42:50,757] Trial 37 finished with value: 37665.6146895926 and parameters: {'learning_rate': 0.0006719476941006434, 'batch_size': 32, 'exploration_final_eps': 0.07055217955037113}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:43:41,786] Trial 38 finished with value: 16819.61357768012 and parameters: {'learning_rate': 0.00032930168079241755, 'batch_size': 64, 'exploration_final_eps': 0.023210977266359255}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:44:38,879] Trial 39 finished with value: 46092.62156956784 and parameters: {'learning_rate': 0.0004746469290157757, 'batch_size': 128, 'exploration_final_eps': 0.017389884076624004}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:45:30,971] Trial 40 finished with value: 55902.04682572665 and parameters: {'learning_rate': 0.0008008773215120193, 'batch_size': 128, 'exploration_final_eps': 0.03565497656355491}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:46:26,239] Trial 41 finished with value: 62808.04652827197 and parameters: {'learning_rate': 0.0009370115218413294, 'batch_size': 128, 'exploration_final_eps': 0.034167933219483276}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:47:20,763] Trial 42 finished with value: 57505.68958526509 and parameters: {'learning_rate': 0.000586242622218547, 'batch_size': 128, 'exploration_final_eps': 0.02953381378918005}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:48:14,701] Trial 43 finished with value: 51471.49403953719 and parameters: {'learning_rate': 0.0008336359589901833, 'batch_size': 128, 'exploration_final_eps': 0.0487193528290638}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:49:12,743] Trial 44 finished with value: 64072.63293531517 and parameters: {'learning_rate': 0.0006184532231973555, 'batch_size': 256, 'exploration_final_eps': 0.02419805805630912}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:50:14,725] Trial 45 finished with value: 40158.32366363334 and parameters: {'learning_rate': 0.000277967676354662, 'batch_size': 256, 'exploration_final_eps': 0.024577923935746763}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:51:17,130] Trial 46 finished with value: 17815.17523450379 and parameters: {'learning_rate': 0.00019156268678071148, 'batch_size': 256, 'exploration_final_eps': 0.02242238019224543}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:52:20,283] Trial 47 finished with value: 52620.36126700551 and parameters: {'learning_rate': 0.0005970954610923702, 'batch_size': 256, 'exploration_final_eps': 0.016861472328226497}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:53:21,367] Trial 48 finished with value: 63692.57835277192 and parameters: {'learning_rate': 0.0004418078651047304, 'batch_size': 256, 'exploration_final_eps': 0.014991027148060268}. Best is trial 31 with value: 68603.36335527191.
# [I 2026-01-28 21:54:20,063] Trial 49 finished with value: 54614.46011953324 and parameters: {'learning_rate': 0.00043718119279652465, 'batch_size': 256, 'exploration_final_eps': 0.01598745361440521}. Best is trial 31 with value: 68603.36335527191.
# Best hyperparameters:  {'learning_rate': 0.0009638038112182319, 'batch_size': 128, 'exploration_final_eps': 0.0388671486044139}

# %%
# Visualize the Optuna study results
create_optuna_study_dashboard(study)

# %%
# Train with best hyperparameters and evaluate across multiple seeds
TRAIN_CONFIG["learning_rate"] = 0.0009638038112182319
TRAIN_CONFIG["batch_size"] = 128
TRAIN_CONFIG["exploration_final_eps"] = 0.0388671486044139
TRAIN_CONFIG["total_timesteps"] = 200000

seed_rewards = []

for seed_idx in range(5):
    np.random.seed(seed_idx)
    random.seed(seed_idx)
    
    # Re-initialize environments with new seed
    train_env = DQNWrapper(train_env_raw, reward_shape=REWARD_SHAPING, num_actions=NUM_ACTIONS)
    train_env.reset(seed=seed_idx)
    
    val_env = DQNWrapper(val_env_raw, reward_shape=REWARD_SHAPING, num_actions=NUM_ACTIONS)
    val_env.reset(seed=seed_idx)
    
    # Create and train model
    policy_kwargs = dict(net_arch=[256, 256, 128])
    model = DQN(
        "MlpPolicy",
        train_env,
        verbose=1,
        learning_rate=TRAIN_CONFIG["learning_rate"],
        buffer_size=TRAIN_CONFIG["buffer_size"],
        learning_starts=TRAIN_CONFIG["learning_starts"],
        batch_size=TRAIN_CONFIG["batch_size"],
        train_freq=TRAIN_CONFIG["train_freq"],
        gradient_steps=TRAIN_CONFIG["gradient_steps"],
        target_update_interval=TRAIN_CONFIG["target_update_interval"],
        gamma=TRAIN_CONFIG["gamma"],
        exploration_fraction=TRAIN_CONFIG["exploration_fraction"],
        exploration_initial_eps=TRAIN_CONFIG["exploration_initial_eps"],
        exploration_final_eps=TRAIN_CONFIG["exploration_final_eps"],
        policy_kwargs=policy_kwargs,
    )
    
    # Train the model
    model.learn(total_timesteps=TRAIN_CONFIG["total_timesteps"], log_interval=10)
    
    # Evaluate on validation environment
    val_env.reset(seed=seed_idx)
    val_env.reward_shape = False
    
    obs, _ = val_env.reset(seed=seed_idx)
    obs = np.array(obs, dtype=np.float32)
    done = False
    episode_rewards = []
    water_levels = []
    action_history = []
    
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        action = int(action)
        obs, reward, terminated, truncated, _ = val_env.step(action)
        done = terminated or truncated
        episode_rewards.append(reward)
        water_levels.append(val_env.env.volume)
        action_history.append(action)
        obs = np.array(obs, dtype=np.float32)
    
    total_reward = sum(episode_rewards)
    seed_rewards.append(episode_rewards)
    
    print(f"Seed {seed_idx + 1} - Total reward: {total_reward:.2f}")

# Save the best model
model.save("dqn_model_5bins_reward_shaping")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Seed 1 - Total reward: 57732.08
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Seed 2 - Total reward: 69320.58
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Seed 3 - Total reward: 65777.00
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Seed 4 - Total reward: 63719.87
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Seed 5 - Total reward: 60767.87

# %%
seed_results = {
    "Seed: 1" :seed_rewards[0],
    "Seed: 2" : seed_rewards[1],
    "Seed: 3" : seed_rewards[2],
    "Seed: 4" : seed_rewards[3],
    "Seed: 5" : seed_rewards[4]
}
plot_cumulative_rewards(seed_results)

# %% [markdown]
# ### Model Performance
#
# We visualize the performance of the model using multiple visualizations.

# %%
# Create comprehensive performance dashboard using the last trained model
create_performance_dashboard(water_levels, episode_rewards, action_history, max_volume=50000)
